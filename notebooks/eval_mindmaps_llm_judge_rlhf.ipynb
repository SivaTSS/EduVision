# %%
import os
import json
from langchain.chat_models import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage
import re
import requests

# %%
def load_api_key(path: str = "../keys.json") -> None:
    """Load OpenAI API key from a JSON file into environment."""
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    os.environ["OPENAI_API_KEY"] = data.get("openai_api_key")


def evaluate_two_mindmaps(ground_truth_path: str, prediction_path: str) -> dict:
    """Evaluate a single pair of ground-truth vs generated mind maps using GPT-4o-mini.

    Returns a dict of scores and comments for Visual, Cognitive, Functional, Structural, and overall."""
    # Read files
    with open(ground_truth_path, 'r', encoding='utf-8') as f:
        ground_truth = f.read().strip()
    with open(prediction_path, 'r', encoding='utf-8') as f:
        prediction = f.read().strip()

    prompt = f"""
You are an expert evaluator. Compare two mind maps based on the following dimensions:

1. **Cognitive Indicators**: How easily can a user understand and mentally process the information?  
   Consider clarity, flow of ideas, and thematic relevance.

2. **Structural Indicators**: How well-organized and logically complete is the mind map?  
   Consider grouping of ideas, coverage of key concepts, level of detail, and consistent hierarchy.

Scoring Instructions (Use a 1–7 Likert scale):
- Use **4** if the generated mind map is about equal in quality to the ground truth.
- Use **5–7** if the generated mind map is better than the ground truth (7 = much better).
- Use **3–1** if the generated mind map is worse than the ground truth (1 = much worse).

Return your evaluation in the following JSON format (no extra text):

{{
  "cognitive_score": int,
  "cognitive_comment": "string",
  "structural_score": int,
  "structural_comment": "string"
}}

Ground Truth Mind Map:
{ground_truth}

Generated Mind Map:
{prediction}
"""
    api_key = os.getenv("OPENAI_API_KEY")
    if not api_key:
        raise RuntimeError("OPENAI_API_KEY not set — run load_api_key() first.")

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "model": "gpt-4o-mini",
        "messages": [
            {"role": "system", "content": "You are a strict evaluator of mind maps."},
            {"role": "user", "content": prompt}
        ],
        "temperature": 0
    }

    response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
    response.raise_for_status()

    text = response.json()["choices"][0]["message"]["content"].strip()
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        match = re.search(r"\{.*\}", text, re.S)
        if match:
            return json.loads(match.group())
        raise

# %%
load_api_key()

# Replace these with your two file paths
ground_truth_file = "../data/tqa_train_val_test/test/mindmap_text_v1/mermaid_code_L_0001.txt"
prediction_file = "../data/tqa_train_val_test/test/test_predictions_rlhf/prediction_L_0001.txt"

result = evaluate_two_mindmaps(ground_truth_file, prediction_file)
print(json.dumps(result, indent=2))
# Out:
# {
#   "cognitive_score": 4,
#   "cognitive_comment": "The generated mind map presents information in a clear manner, but the flow of ideas is less cohesive compared to the ground truth. The thematic relevance is maintained, but some connections are less intuitive.",
#   "structural_score": 3,
#   "structural_comment": "The organization of the generated mind map is less logical and complete than the ground truth. Key concepts are present, but the grouping of ideas lacks consistency and some details are missing, leading to a weaker hierarchy."
# }

# %%
load_api_key()

# Replace these with your two file paths
ground_truth_file = "../data/tqa_train_val_test/test/mindmap_text_v1/mermaid_code_L_0001.txt"
prediction_file = "../data/gen_mindmap/mindmap_L0001.txt"

result = evaluate_two_mindmaps(ground_truth_file, prediction_file)
print(json.dumps(result, indent=2))
# Out:
# {
#   "cognitive_score": 5,
#   "cognitive_comment": "The generated mind map presents information in a clear and organized manner, making it easy for users to understand the relationships between concepts. However, some thematic relevance is slightly less direct compared to the ground truth, which may affect immediate comprehension.",
#   "structural_score": 6,
#   "structural_comment": "The generated mind map is well-organized and covers key concepts effectively, with a logical hierarchy. It provides a good level of detail and groups ideas appropriately, although some areas could benefit from more explicit connections to enhance completeness."
# }

# %%
def evaluate_folder_and_save(ground_truth_folder: str, prediction_folder: str, output_file: str) -> None:
    """
    Evaluate all mind map pairs in the given folders and store the results in a JSON file.

    Ground truth files are expected to be named like:
      mermaid_code_L_0001.txt

    The corresponding prediction file should be named:
      prediction_L_0001.txt
    """
    evaluations = {}
    # Iterate over files in the ground truth folder.
    for filename in os.listdir(ground_truth_folder):
        # Check that the file follows the naming pattern.
        if not filename.startswith("mermaid_code_"):
            continue

        gt_path = os.path.join(ground_truth_folder, filename)
        # Replace the prefix to create the prediction file name.
        pred_filename = filename.replace("mermaid_code_", "prediction_")
        pred_path = os.path.join(prediction_folder, pred_filename)
        
        if os.path.isfile(gt_path) and os.path.isfile(pred_path):
            try:
                result = evaluate_two_mindmaps(gt_path, pred_path)
                evaluations[filename] = result
                print(f"Evaluated: {filename} and {pred_filename}")
            except Exception as e:
                print(f"Error evaluating {filename}: {e}")
        else:
            print(f"Skipping {filename}: corresponding prediction file {pred_filename} not found.")

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(evaluations, f, indent=2)
    print(f"Saved evaluations to {output_file}")

# %%
def analyze_results(evaluations_file: str, ground_truth_folder: str, prediction_folder: str) -> None:
    """
    Load evaluations from the JSON file, compute average and standard deviation of scores,
    plot histograms and line plots, and print the best and worst mind map predictions
    (with their comments and full texts) for each category.
    """
    import matplotlib.pyplot as plt
    import seaborn as sns
    import os
    import json
    import statistics

    with open(evaluations_file, 'r', encoding='utf-8') as f:
        evaluations = json.load(f)

    if not evaluations:
        print("No evaluations found in file.")
        return

    score_keys = ["cognitive_score", "structural_score"]

    # Collect scores
    scores = {key: [] for key in score_keys}
    for fname, result in evaluations.items():
        for key in score_keys:
            try:
                scores[key].append((fname, float(result.get(key, 0))))
            except Exception as e:
                print(f"Error processing score for {fname} in {key}: {e}")

    # Compute average and standard deviation
    score_stats = {}
    for key in score_keys:
        values = [score for _, score in scores[key]]
        if values:
            score_stats[key] = {
                "mean": sum(values) / len(values),
                "std": statistics.stdev(values) if len(values) > 1 else 0.0
            }
        else:
            score_stats[key] = {"mean": 0.0, "std": 0.0}

    print("Score Summary:")
    print(json.dumps(score_stats, indent=2))

    # Plotting
    for key in score_keys:
        values = sorted(scores[key], key=lambda x: x[1])
        score_values = [score for _, score in values]

        # Line plot
        plt.figure(figsize=(12, 4))
        plt.plot(score_values, marker='o')
        plt.title(f"Line Plot of {key}")
        plt.xlabel("Sample (sorted by score)")
        plt.ylabel("Score")
        plt.grid(True)
        plt.tight_layout()
        plt.show()

        # Histogram
        plt.figure(figsize=(8, 4))
        sns.histplot(score_values, bins=[0.5 + i for i in range(8)], discrete=True)
        plt.xticks(range(1, 8))
        plt.title(f"Distribution of {key} scores")
        plt.xlabel("Score (Likert scale)")
        plt.ylabel("Frequency")
        plt.grid(axis="y")
        plt.tight_layout()
        plt.show()

    # Print best/worst samples
    for key in score_keys:
        if not scores[key]:
            continue
        worst = min(scores[key], key=lambda x: x[1])
        best = max(scores[key], key=lambda x: x[1])
        comment_key = key.replace("_score", "_comment")

        for label, fname in [("Worst", worst[0]), ("Best", best[0])]:
            score = dict(scores[key])[fname]
            comment = evaluations[fname].get(comment_key, '')
            print(f"\nCategory: {key} - {label}: {fname} with score {score}")
            print(f"Comment: {comment}")

            gt_file = os.path.join(ground_truth_folder, fname)
            pred_file = os.path.join(prediction_folder, fname.replace("mermaid_code_", "prediction_"))

            try:
                with open(gt_file, 'r', encoding='utf-8') as f:
                    gt_content = f.read().strip()
                with open(pred_file, 'r', encoding='utf-8') as f:
                    pred_content = f.read().strip()

                print("Ground Truth:")
                print(gt_content)
                print("\nPrediction:")
                print(pred_content)
            except Exception as e:
                print(f"Error loading files for {fname}: {e}")

# %%
load_api_key()

# Set your folder paths (adjust as needed)
ground_truth_folder = "../data/tqa_train_val_test/test/mindmap_text_v1"
prediction_folder = "../data/tqa_train_val_test/test/test_predictions_rlhf"
output_file = "../data/tqa_train_val_test/test/llm_judge_evaluation_results_rlhf.json"

# %%
# Step 1: Evaluate all mind map pairs and save the individual JSON outputs.
evaluate_folder_and_save(ground_truth_folder, prediction_folder, output_file)
# Out:
# Evaluated: mermaid_code_L_0379.txt and prediction_L_0379.txt
# Evaluated: mermaid_code_L_0988.txt and prediction_L_0988.txt
# Evaluated: mermaid_code_L_0922.txt and prediction_L_0922.txt
# Evaluated: mermaid_code_L_0696.txt and prediction_L_0696.txt
# Evaluated: mermaid_code_L_1075.txt and prediction_L_1075.txt
# Evaluated: mermaid_code_L_0254.txt and prediction_L_0254.txt
# Evaluated: mermaid_code_L_0711.txt and prediction_L_0711.txt
# Evaluated: mermaid_code_L_0559.txt and prediction_L_0559.txt
# Evaluated: mermaid_code_L_0588.txt and prediction_L_0588.txt
# Evaluated: mermaid_code_L_0377.txt and prediction_L_0377.txt
# Evaluated: mermaid_code_L_0632.txt and prediction_L_0632.txt
# Evaluated: mermaid_code_L_0195.txt and prediction_L_0195.txt
# Evaluated: mermaid_code_L_0029.txt and prediction_L_0029.txt
# Evaluated: mermaid_code_L_0448.txt and prediction_L_0448.txt
# Evaluated: mermaid_code_L_0600.txt and prediction_L_0600.txt
# Evaluated: mermaid_code_L_0339.txt and prediction_L_0339.txt
# Evaluated: mermaid_code_L_0672.txt and prediction_L_0672.txt
# Evaluated: mermaid_code_L_0565.txt and prediction_L_0565.txt
# Evaluated: mermaid_code_L_0562.txt and prediction_L_0562.txt
# Evaluated: mermaid_code_L_0027.txt and prediction_L_0027.txt
# Evaluated: mermaid_code_L_0446.txt and prediction_L_0446.txt
# Evaluated: mermaid_code_L_0497.txt and prediction_L_0497.txt
# Evaluated: mermaid_code_L_0573.txt and prediction_L_0573.txt
# Evaluated: mermaid_code_L_0486.txt and prediction_L_0486.txt
# Evaluated: mermaid_code_L_0747.txt and prediction_L_0747.txt
# Evaluated: mermaid_code_L_0450.txt and prediction_L_0450.txt
# Evaluated: mermaid_code_L_0508.txt and prediction_L_0508.txt
# Evaluated: mermaid_code_L_0115.txt and prediction_L_0115.txt
# Evaluated: mermaid_code_L_0574.txt and prediction_L_0574.txt
# Evaluated: mermaid_code_L_0974.txt and prediction_L_0974.txt
# Evaluated: mermaid_code_L_0611.txt and prediction_L_0611.txt
# Evaluated: mermaid_code_L_0354.txt and prediction_L_0354.txt
# Evaluated: mermaid_code_L_0353.txt and prediction_L_0353.txt
# Evaluated: mermaid_code_L_0382.txt and prediction_L_0382.txt
# Evaluated: mermaid_code_L_0160.txt and prediction_L_0160.txt
# Evaluated: mermaid_code_L_0973.txt and prediction_L_0973.txt
# Evaluated: mermaid_code_L_0707.txt and prediction_L_0707.txt
# Evaluated: mermaid_code_L_0366.txt and prediction_L_0366.txt
# Evaluated: mermaid_code_L_0534.txt and prediction_L_0534.txt
# Evaluated: mermaid_code_L_0245.txt and prediction_L_0245.txt
# Evaluated: mermaid_code_L_0152.txt and prediction_L_0152.txt
# Evaluated: mermaid_code_L_0700.txt and prediction_L_0700.txt
# Evaluated: mermaid_code_L_0361.txt and prediction_L_0361.txt
# Evaluated: mermaid_code_L_1018.txt and prediction_L_1018.txt
# Evaluated: mermaid_code_L_0658.txt and prediction_L_0658.txt
# Evaluated: mermaid_code_L_0239.txt and prediction_L_0239.txt
# Evaluated: mermaid_code_L_0689.txt and prediction_L_0689.txt
# Evaluated: mermaid_code_L_0687.txt and prediction_L_0687.txt
# Evaluated: mermaid_code_L_0368.txt and prediction_L_0368.txt
# Evaluated: mermaid_code_L_1011.txt and prediction_L_1011.txt
# Evaluated: mermaid_code_L_0651.txt and prediction_L_0651.txt
# Evaluated: mermaid_code_L_0597.txt and prediction_L_0597.txt
# Evaluated: mermaid_code_L_0462.txt and prediction_L_0462.txt
# Evaluated: mermaid_code_L_0674.txt and prediction_L_0674.txt
# Evaluated: mermaid_code_L_0102.txt and prediction_L_0102.txt
# Evaluated: mermaid_code_L_0563.txt and prediction_L_0563.txt
# Evaluated: mermaid_code_L_0026.txt and prediction_L_0026.txt
# Evaluated: mermaid_code_L_0447.txt and prediction_L_0447.txt
# Evaluated: mermaid_code_L_0496.txt and prediction_L_0496.txt
# Evaluated: mermaid_code_L_0491.txt and prediction_L_0491.txt
# Evaluated: mermaid_code_L_0673.txt and prediction_L_0673.txt
# Evaluated: mermaid_code_L_0564.txt and prediction_L_0564.txt
# Evaluated: mermaid_code_L_0918.txt and prediction_L_0918.txt
# Evaluated: mermaid_code_L_1046.txt and prediction_L_1046.txt
# Evaluated: mermaid_code_L_0028.txt and prediction_L_0028.txt
# Evaluated: mermaid_code_L_0498.txt and prediction_L_0498.txt
# Evaluated: mermaid_code_L_0558.txt and prediction_L_0558.txt
# Evaluated: mermaid_code_L_0376.txt and prediction_L_0376.txt
# Evaluated: mermaid_code_L_0524.txt and prediction_L_0524.txt
# Evaluated: mermaid_code_L_0194.txt and prediction_L_0194.txt
# Evaluated: mermaid_code_L_0633.txt and prediction_L_0633.txt
# Evaluated: mermaid_code_L_0634.txt and prediction_L_0634.txt
# Evaluated: mermaid_code_L_0193.txt and prediction_L_0193.txt
# Evaluated: mermaid_code_L_0699.txt and prediction_L_0699.txt
# Evaluated: mermaid_code_L_1008.txt and prediction_L_1008.txt
# Evaluated: mermaid_code_L_0807.txt and prediction_L_0807.txt
# Error evaluating mermaid_code_L_1006.txt: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Evaluated: mermaid_code_L_0556.txt and prediction_L_0556.txt
# Evaluated: mermaid_code_L_0690.txt and prediction_L_0690.txt
# Evaluated: mermaid_code_L_0378.txt and prediction_L_0378.txt
# Evaluated: mermaid_code_L_0013.txt and prediction_L_0013.txt
# Evaluated: mermaid_code_L_0650.txt and prediction_L_0650.txt
# Evaluated: mermaid_code_L_0126.txt and prediction_L_0126.txt
# Evaluated: mermaid_code_L_0681.txt and prediction_L_0681.txt
# Evaluated: mermaid_code_L_0463.txt and prediction_L_0463.txt
# Evaluated: mermaid_code_L_0464.txt and prediction_L_0464.txt
# Evaluated: mermaid_code_L_0005.txt and prediction_L_0005.txt
# Evaluated: mermaid_code_L_0657.txt and prediction_L_0657.txt
# Evaluated: mermaid_code_L_1017.txt and prediction_L_1017.txt
# Evaluated: mermaid_code_L_0686.txt and prediction_L_0686.txt
# Evaluated: mermaid_code_L_0182.txt and prediction_L_0182.txt
# Evaluated: mermaid_code_L_0416.txt and prediction_L_0416.txt
# Evaluated: mermaid_code_L_0701.txt and prediction_L_0701.txt
# Evaluated: mermaid_code_L_0360.txt and prediction_L_0360.txt
# Evaluated: mermaid_code_L_0411.txt and prediction_L_0411.txt
# Evaluated: mermaid_code_L_0706.txt and prediction_L_0706.txt
# Evaluated: mermaid_code_L_0367.txt and prediction_L_0367.txt
# Evaluated: mermaid_code_L_0598.txt and prediction_L_0598.txt
# Evaluated: mermaid_code_L_0622.txt and prediction_L_0622.txt
# Evaluated: mermaid_code_L_0535.txt and prediction_L_0535.txt
# Evaluated: mermaid_code_L_0352.txt and prediction_L_0352.txt
# Evaluated: mermaid_code_L_0276.txt and prediction_L_0276.txt
# Evaluated: mermaid_code_L_0617.txt and prediction_L_0617.txt
# Evaluated: mermaid_code_L_0799.txt and prediction_L_0799.txt
# Evaluated: mermaid_code_L_0093.txt and prediction_L_0093.txt
# Evaluated: mermaid_code_L_0909.txt and prediction_L_0909.txt
# Evaluated: mermaid_code_L_0746.txt and prediction_L_0746.txt
# Evaluated: mermaid_code_L_0168.txt and prediction_L_0168.txt
# Evaluated: mermaid_code_L_0575.txt and prediction_L_0575.txt
# Evaluated: mermaid_code_L_0900.txt and prediction_L_0900.txt
# Evaluated: mermaid_code_L_0487.txt and prediction_L_0487.txt
# Evaluated: mermaid_code_L_0770.txt and prediction_L_0770.txt
# Evaluated: mermaid_code_L_0298.txt and prediction_L_0298.txt
# Evaluated: mermaid_code_L_0592.txt and prediction_L_0592.txt
# Evaluated: mermaid_code_L_1014.txt and prediction_L_1014.txt
# Evaluated: mermaid_code_L_0685.txt and prediction_L_0685.txt
# Evaluated: mermaid_code_L_0595.txt and prediction_L_0595.txt
# Evaluated: mermaid_code_L_0653.txt and prediction_L_0653.txt
# Evaluated: mermaid_code_L_1013.txt and prediction_L_1013.txt
# Evaluated: mermaid_code_L_0001.txt and prediction_L_0001.txt
# Evaluated: mermaid_code_L_0412.txt and prediction_L_0412.txt
# Evaluated: mermaid_code_L_0364.txt and prediction_L_0364.txt
# Evaluated: mermaid_code_L_0536.txt and prediction_L_0536.txt
# Evaluated: mermaid_code_L_0296.txt and prediction_L_0296.txt
# Evaluated: mermaid_code_L_0363.txt and prediction_L_0363.txt
# Evaluated: mermaid_code_L_0420.txt and prediction_L_0420.txt
# Evaluated: mermaid_code_L_0578.txt and prediction_L_0578.txt
# Evaluated: mermaid_code_L_0730.txt and prediction_L_0730.txt
# Evaluated: mermaid_code_L_0380.txt and prediction_L_0380.txt
# Evaluated: mermaid_code_L_0668.txt and prediction_L_0668.txt
# Evaluated: mermaid_code_L_0503.txt and prediction_L_0503.txt
# Evaluated: mermaid_code_L_0275.txt and prediction_L_0275.txt
# Evaluated: mermaid_code_L_0429.txt and prediction_L_0429.txt
# Evaluated: mermaid_code_L_0666.txt and prediction_L_0666.txt
# Evaluated: mermaid_code_L_0745.txt and prediction_L_0745.txt
# Evaluated: mermaid_code_L_0452.txt and prediction_L_0452.txt
# Evaluated: mermaid_code_L_0978.txt and prediction_L_0978.txt
# Evaluated: mermaid_code_L_0576.txt and prediction_L_0576.txt
# Evaluated: mermaid_code_L_0200.txt and prediction_L_0200.txt
# Evaluated: mermaid_code_L_0443.txt and prediction_L_0443.txt
# Evaluated: mermaid_code_L_0492.txt and prediction_L_0492.txt
# Evaluated: mermaid_code_L_0670.txt and prediction_L_0670.txt
# Evaluated: mermaid_code_L_0567.txt and prediction_L_0567.txt
# Evaluated: mermaid_code_L_0560.txt and prediction_L_0560.txt
# Evaluated: mermaid_code_L_0101.txt and prediction_L_0101.txt
# Evaluated: mermaid_code_L_0438.txt and prediction_L_0438.txt
# Evaluated: mermaid_code_L_0444.txt and prediction_L_0444.txt
# Evaluated: mermaid_code_L_0332.txt and prediction_L_0332.txt
# Evaluated: mermaid_code_L_0495.txt and prediction_L_0495.txt
# Evaluated: mermaid_code_L_0895.txt and prediction_L_0895.txt
# Evaluated: mermaid_code_L_0605.txt and prediction_L_0605.txt
# Evaluated: mermaid_code_L_0431.txt and prediction_L_0431.txt
# Evaluated: mermaid_code_L_0520.txt and prediction_L_0520.txt
# Evaluated: mermaid_code_L_0983.txt and prediction_L_0983.txt
# Evaluated: mermaid_code_L_0372.txt and prediction_L_0372.txt
# Evaluated: mermaid_code_L_0713.txt and prediction_L_0713.txt
# Evaluated: mermaid_code_L_0527.txt and prediction_L_0527.txt
# Evaluated: mermaid_code_L_0555.txt and prediction_L_0555.txt
# Evaluated: mermaid_code_L_0584.txt and prediction_L_0584.txt
# Evaluated: mermaid_code_L_0529.txt and prediction_L_0529.txt
# Evaluated: mermaid_code_L_0639.txt and prediction_L_0639.txt
# Evaluated: mermaid_code_L_0482.txt and prediction_L_0482.txt
# Evaluated: mermaid_code_L_0325.txt and prediction_L_0325.txt
# Evaluated: mermaid_code_L_0032.txt and prediction_L_0032.txt
# Evaluated: mermaid_code_L_0795.txt and prediction_L_0795.txt
# Evaluated: mermaid_code_L_0359.txt and prediction_L_0359.txt
# Evaluated: mermaid_code_L_0388.txt and prediction_L_0388.txt
# Evaluated: mermaid_code_L_0577.txt and prediction_L_0577.txt
# Evaluated: mermaid_code_L_1020.txt and prediction_L_1020.txt
# Evaluated: mermaid_code_L_0660.txt and prediction_L_0660.txt
# Evaluated: mermaid_code_L_0826.txt and prediction_L_0826.txt
# Evaluated: mermaid_code_L_0381.txt and prediction_L_0381.txt
# Evaluated: mermaid_code_L_0669.txt and prediction_L_0669.txt
# Evaluated: mermaid_code_L_0164.txt and prediction_L_0164.txt
# Evaluated: mermaid_code_L_0357.txt and prediction_L_0357.txt
# Evaluated: mermaid_code_L_0297.txt and prediction_L_0297.txt
# Evaluated: mermaid_code_L_0414.txt and prediction_L_0414.txt
# Evaluated: mermaid_code_L_0703.txt and prediction_L_0703.txt
# Evaluated: mermaid_code_L_0365.txt and prediction_L_0365.txt
# Evaluated: mermaid_code_L_0620.txt and prediction_L_0620.txt
# Evaluated: mermaid_code_L_0290.txt and prediction_L_0290.txt
# Evaluated: mermaid_code_L_0594.txt and prediction_L_0594.txt
# Evaluated: mermaid_code_L_0461.txt and prediction_L_0461.txt
# Evaluated: mermaid_code_L_0466.txt and prediction_L_0466.txt
# Evaluated: mermaid_code_L_0814.txt and prediction_L_0814.txt
# Evaluated: mermaid_code_L_0593.txt and prediction_L_0593.txt
# Evaluated: mermaid_code_L_0684.txt and prediction_L_0684.txt
# Evaluated: mermaid_code_L_0644.txt and prediction_L_0644.txt
# Evaluated: mermaid_code_L_0554.txt and prediction_L_0554.txt
# Evaluated: mermaid_code_L_0585.txt and prediction_L_0585.txt
# Evaluated: mermaid_code_L_0149.txt and prediction_L_0149.txt
# Evaluated: mermaid_code_L_0528.txt and prediction_L_0528.txt
# Evaluated: mermaid_code_L_0526.txt and prediction_L_0526.txt
# Evaluated: mermaid_code_L_0631.txt and prediction_L_0631.txt
# Evaluated: mermaid_code_L_0636.txt and prediction_L_0636.txt
# Evaluated: mermaid_code_L_0373.txt and prediction_L_0373.txt
# Evaluated: mermaid_code_L_0712.txt and prediction_L_0712.txt
# Evaluated: mermaid_code_L_1043.txt and prediction_L_1043.txt
# Evaluated: mermaid_code_L_0430.txt and prediction_L_0430.txt
# Evaluated: mermaid_code_L_0219.txt and prediction_L_0219.txt
# Evaluated: mermaid_code_L_1044.txt and prediction_L_1044.txt
# Evaluated: mermaid_code_L_0604.txt and prediction_L_0604.txt
# Evaluated: mermaid_code_L_0961.txt and prediction_L_0961.txt
# Evaluated: mermaid_code_L_0839.txt and prediction_L_0839.txt
# Evaluated: mermaid_code_L_0561.txt and prediction_L_0561.txt
# Evaluated: mermaid_code_L_0100.txt and prediction_L_0100.txt
# Evaluated: mermaid_code_L_0445.txt and prediction_L_0445.txt
# Evaluated: mermaid_code_L_0024.txt and prediction_L_0024.txt
# Evaluated: mermaid_code_L_0671.txt and prediction_L_0671.txt
# Evaluated: mermaid_code_L_0566.txt and prediction_L_0566.txt
# Saved evaluations to ../data/tqa_train_val_test/test/llm_judge_evaluation_results_rlhf.json

# %%
import matplotlib.pyplot as plt
# Step 2: Later, load the saved JSON file, compute average metrics, and plot histograms.
analyze_results(output_file,ground_truth_folder, prediction_folder)
# Out:
# Score Summary:
# {
#   "cognitive_score": {
#     "mean": 4.411483253588517,
#     "std": 0.695495258622434
#   },
#   "structural_score": {
#     "mean": 3.7942583732057416,
#     "std": 1.0051624200171076
#   }
# }
# Category: cognitive_score - Worst: mermaid_code_L_0028.txt with score 2.0
# Comment: The generated mind map lacks clarity and does not present the information in a coherent manner, making it difficult for users to understand and process the information effectively.
# Ground Truth:
# mindmap
#   Weather Forecasting
#     Meteorologists
#       Definition
#       Role in Weather Prediction
#     Weather Prediction
#       Challenges
#         Complexity
#         Factors Involved
#       Methods
#         Rules of Thumb
#         Data Collection
#           Weather Instruments
#             Barometer
#             Thermometer
#             Anemometer
#             Rain Gauge
#             Hygrometer
#             Wind Vane
#             Snow Gauge
#           Weather Stations
#           Weather Balloons
#           Satellites
#           Radar
#         Data Analysis
#           Computer Models
#     Weather Maps
#       Purpose
#         Actual Weather
#         Predicted Weather
#       Types of Information
#         Air Pressure
#           Isobars
#         Temperature
#           Isotherms
#         Other Conditions
#     Technology in Forecasting
#       Data Gathering
#       Data Analysis
#
# Prediction:
# This Mermaid syntax generates a
#
# Category: cognitive_score - Best: mermaid_code_L_0379.txt with score 5.0
# Comment: The generated mind map presents information in a clear manner, but the inclusion of less relevant details (like 'Human Beings') slightly detracts from thematic focus compared to the ground truth.
# Ground Truth:
# mindmap
#   Mammals
#     Traits
#       Fur or Hair
#       Mammary Glands
#     Body Temperature Regulation
#       Heat Generation
#         High Metabolism
#         Shivering
#       Heat Conservation
#         Insulating Fur
#         Layer of Fat
#       Heat Loss
#         Increased Blood Flow
#         Sweating and Panting
#     Diet Variation
#       Herbivores
#         Examples: Rabbits, Deer, Manatees
#       Carnivores
#         Examples: Wolves, Whales, Hyenas
#       Omnivores
#         Examples: Bears, Humans, Chimpanzees
#         Frugivores
#     Reproductive Methods
#       Monotremes
#         Egg-laying
#         Examples: Platypus, Echidna
#       Marsupials
#         Pouch Development
#         Examples: Kangaroos, Koalas
#       Placental Mammals
#         Live Birth
#         Examples: Humans, Deer
#     Classification
#       Subclasses
#         Monotremes
#         Marsupials
#         Placental Mammals
#       Orders
#         Insectivora
#         Carnivora
#         Rodentia
#         Lagomorpha
#         Artiodactyla
#         Cetacea
#         Primates
#
# Prediction:
# mindmap
#   Mammals
#     Definition
#       Endothermic vertebrates
#       Four limbs
#       Produce amniotic eggs
#     Traits
#       Fur or hair
#       Mammary glands
#     Behaviors
#       Play
#       Complex behaviors
#     Body Temperature Regulation
#       High metabolism
#       Shivering
#       Insulating hair or fur
#       Layer of fat under skin
#       Sweating or panting
#     Diets
#       Herbivores
#       Carnivores
#       Omnivores
#         Frugivores
#     Reproduction
#       Separate sexes
#       Sexual reproduction
#       Oviparous (monotremes)
#       Viviparous (marsupials, placental mammals)
#     Classification
#       Subclasses
#         Monotreme
#         Marsupial
#         Placental
#       Orders
#         Insectivora
#         Chiroptera
#         Carnivora
#         Rodentia
#         Lagomorpha
#         Artiodactyla
#         Cetacea
#         Primates
#     Human Beings
#       Placental mammal
#       Order Primates
#       Unique traits of this order
#
# Category: structural_score - Worst: mermaid_code_L_0588.txt with score 2.0
# Comment: The organization of the generated mind map is weak. Key concepts are missing or poorly grouped, and there is a lack of consistent hierarchy, which affects the overall logical completeness.
# Ground Truth:
# mindmap
#   Lizards and Snakes
#     Reptile Diversity
#       Species in Australian Desert
#         Sand Dune Capacity
#         Mammals vs. Reptiles
#         Physiological Adaptations
#       Goanna Lizards
#         Egg Laying Habits
#         Environmental Influences
#     Komodo Dragon
#       Hunting Strategies
#       Effectiveness for Mammals
#     Arctic Snakes
#       Activity Duration
#       Color Adaptations
#         Black vs. Zigzag Patterns
#       Female Advantages
#     Characteristics of Lizards
#       Physical Traits
#         Four Limbs
#         External Ears
#         Movable Eyelids
#         Long Tail
#       Behavior
#         Communication
#         Camouflage
#     Differences Between Snakes and Lizards
#       Physical Differences
#         Eyelids and Limbs
#         Body Structure
#       Feeding Mechanisms
#         Snake Jaw Structure
#         Prey Consumption
#     Snake Features
#       Species Diversity
#         Size Range
#         Habitat Distribution
#       Feeding and Digestion
#         Carnivorous Diet
#         Swallowing Mechanism
#         Venomous vs. Non-Venomous
#       Reproductive Strategies
#         Internal Fertilization
#         Egg Laying and Abandonment
#
# Prediction:
# mindmap
#   Lizards and Snakes
#     Characteristics
#       Four limbs
#       External ears
#       Movable eyelids
#       Short neck
#       Long tail
#       Carnivorous diet
#       Vision and color vision
#       Camouflage and communication
#     Differences from Snakes
#       Eyelids
#       Limbs
#       External ears
#       Forelimbs
#     Snake Jaw
#       Flexible lower jaw
#       Multiple joints in skull
#     Reproduction
#       Internal fertilization
#       Egg laying
#       Abandonment of eggs
#     Habitats
#       Deserts of Australia
#       Arctic Circle
#     Species
#       Komodo dragon
#       Goanna lizard
#       Varanus spp.
#       Black snakes
#       Zigzag patterned snakes
#     Size
#       Smallest: 4 inches
#       Largest: 10 feet
#     Diet
#       Insects
#       Birds
#       Mammals
#       Fish
#       Snails
#       Eggs
#     Venom
#       Used for killing prey
#       Not for self-defense
#     Molting
#       Shedding of outer skin layer
#       Replacement of old skin
#       Removal of parasites
#     Carnivorous
#       Eating small animals
#       Swallowing prey whole
#     Desert
#
# Category: structural_score - Best: mermaid_code_L_0974.txt with score 6.0
# Comment: The generated mind map is well-organized and covers key concepts effectively, with a consistent hierarchy. It introduces additional relevant sections, such as 'Pressure Explanation,' which enhances the overall understanding of the topic, although it slightly diverges from the original structure.
# Ground Truth:
# mindmap
#   Oceanic Pressure
#     Water Pressure Changes
#       Increases with Depth
#         10 kPa per Meter
#         Double at 30 Meters
#         Extreme at 500 Meters
#         Tremendous at 11,000 Meters
#     Effects on Divers
#       Difficulty Exploring Deep Ocean
#       Use of Pressure-Resistant Vehicles
#       Scuba Diving Limitations
#         Safe Depth Limit
#         Slow Ascent Required
#           Stops for Pressure Adjustment
#           Risks of Rapid Ascent
#             Gas Bubbles Formation
#               Less Gas Solubility at Lower Pressure
#
# Prediction:
# mindmap
#   Oceanic Pressure
#     Water Pressure Changes
#       Increases with Depth
#         Each Meter: 10 kPa
#         At 30 Meters: Double Surface Pressure
#         At 500 Meters: Too Great for Humans
#         At 11,000 Meters: Tremendous Pressure
#     Diving Safety
#       Scuba Divers
#         Depth Limit: 40 Meters
#         Slow Ascent Required
#         Stops for Pressure Adjustment
#       Deep-Sea Vehicles
#         Pressure-Resistant
#         Allows Exploration
#     Pressure Explanation
#       Definition: Force per Area
#       Increases with Depth
#         More Water Above
#         Greater Pressure
#     Dangers of Rapid Ascent
#       Dissolved Gases Form Bubbles
#         Less Gas Dissolves at Lower Pressure
#         Causes Health Problems
